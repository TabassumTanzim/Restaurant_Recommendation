# %% [markdown]
# ## Foodpanda

# %%
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
from time import sleep
import numpy as np

path = r"/Users/tabassumtanzim/Downloads/chromedriver-mac-arm64/chromedriver"

# Create ChromeOptions object
options = webdriver.ChromeOptions()

# Specify the path to the Chrome driver executable using add_argument
options.add_argument(f"webdriver.chrome.driver={path}")

# Now you can set various options if needed, for example:
# options.add_argument("--headless")  # Run Chrome in headless mode
# options.add_argument("--remote-debugging-port=9222")  # Use any available port number

# Instantiate the Chrome webdriver with the specified options
browser = webdriver.Chrome(options=options)

# Open the TripAdvisor page
# browser.get("https://www.tripadvisor.com/Restaurant_Review-g293936-d14990964-Reviews-Secret_Recipe_Dhanmondi_Flagship-Dhaka_City_Dhaka_Division.html")

browser.get("https://www.foodpanda.com.bd/restaurants/new/?lat=23.7377694&lng=90.3805773&vertical=restaurants&expedition=delivery")
# browser.maximize_window()
# name =browser.find_element(By.XPATH,'//*[@id="component_51"]/div/div[1]/h1').text
# name

# %%
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
from time import sleep
import numpy as np

path = r"/Users/tabassumtanzim/Downloads/chromedriver-mac-arm64/chromedriver"

# Create Chrome object
options = webdriver.ChromeOptions()
options.add_argument(f"webdriver.chrome.driver={path}")

driver = webdriver.Chrome(options=options)
driver.get("https://www.foodpanda.com.bd/restaurants/new/?lat=23.71501&lng=90.41864&vertical=restaurants&expedition=delivery&query=wari+restuarant")



title=[]
cuisine=[]
rating=[]
location='Wari'


for i in range (1,33):
    if (driver.find_element(By.XPATH, '//*[@id="restaurant-listing-root"]/div/div/div[2]/div[2]/div/div/div/div[4]/section/ul/li[' + str(i) + ']/div/a/figure/figcaption/span/span[1]').text != 'Top restaurant'):
        try:
            title.append(driver.find_element(By.XPATH, '//*[@id="restaurant-listing-root"]/div/div/div[2]/div[2]/div/div/div/div[4]/section/ul/li[' + str(i) + ']/div/a/figure/figcaption/span/span[1]').text)
        except:
            title.append(driver.find_element(By.XPATH, '//*[@id="restaurant-listing-root"]/div/div/div[2]/div[2]/div/div/div/div[4]/section/ul/li[' + str(i) + ']/div/a/figure/figcaption/span/span[2]').text)

                                    
        cuisine.append(driver.find_element(By.XPATH, '//*[@id="restaurant-listing-root"]/div/div/div[2]/div[2]/div/div/div/div[4]/section/ul/li[' + str(i) + ']/div/a/figure/figcaption/ul[1]/li[2]/span').text)
      
        try:
            rating.append(driver.find_element(By.XPATH,'//*[@id="restaurant-listing-root"]/div/div/div[2]/div[2]/div/div/div/div[4]/section/ul/li[' + str(i) + ']/div/a/figure/figcaption/span/span[2]/div/div/span[1]').text)
        except:
            rating.append(driver.find_element(By.XPATH,'//*[@id="restaurant-listing-root"]/div/div/div[2]/div[2]/div/div/div/div[4]/section/ul/li[' + str(i) + ']/div/a/figure/figcaption/span/span[3]/div/div/span[1]').text)
              

                          
print(title)        
print(cuisine)
print(rating)
# Out:
# ['Alfresco - Wari', "Khana's-Wari", 'Cafe Appeliano - Wari', 'Star Kabab & Restaurant - Wari', 'Simla Dosa & Mini Chinese - Wari', 'Orange Cafe - Wari', 'KFC Wari', 'Bangaliana Bhoj - Wari', 'Wasabi Wari', 'Well Food - Wari', 'Whatta Bowl - Wari', 'Kacchi Bhai - Wari', 'Pizza Burg - Wari', 'Slieez - Wari', 'Secret Recipe (Standard) - Wari', 'Pizza Hut Wari', 'Paragon Momo- Wari', 'Holy Fries- Wari', 'Little Yellow - Wari', 'Waffle Time - Wari', 'Indulge - Wari', 'Warsi La - Jabab Food', 'Fries & More - Wari']
# ['Fast Food', 'Fast Food', 'Fast Food', 'Bangladeshi', 'Fast Food', 'Cafe', 'Fried Chicken', 'Bangladeshi', 'Dumpling', 'Dessert', 'Rice Dishes', 'Biryani', 'Pizza', 'Fast Food', 'Dessert', 'Pizza', 'Dumpling', 'Fast Food', 'Burgers', 'Dessert', 'Dessert', 'Asian', 'Fast Food']
# ['4/5', '4/5', '3.8/5', '4/5', '3.2/5', '4/5', '4.2/5', '4/5', '4/5', '4.2/5', '3.8/5', '3.9/5', '3.9/5', '4/5', '4.2/5', '3.6/5', '4.1/5', '3.9/5', '4/5', '4.2/5', '4.2/5', '2.3/5', '3.4/5']

# %%
data = {'Location':location,'Restuarants': title, 'Cuisine': cuisine, 'Rating': rating}
df=pd.DataFrame(data)
df
# Out:
#    Location                       Restuarants        Cuisine Rating
# 0      Wari                   Alfresco - Wari      Fast Food    4/5
# 1      Wari                      Khana's-Wari      Fast Food    4/5
# 2      Wari             Cafe Appeliano - Wari      Fast Food  3.8/5
# 3      Wari    Star Kabab & Restaurant - Wari    Bangladeshi    4/5
# 4      Wari  Simla Dosa & Mini Chinese - Wari      Fast Food  3.2/5
# 5      Wari                Orange Cafe - Wari           Cafe    4/5
# 6      Wari              Govinda’s Restaurant    Bangladeshi    4/5
# 7      Wari                          KFC Wari  Fried Chicken  4.2/5
# 8      Wari            Bangaliana Bhoj - Wari    Bangladeshi    4/5
# 9      Wari                       Wasabi Wari       Dumpling    4/5
# 10     Wari                  Well Food - Wari        Dessert  4.2/5
# 11     Wari                Whatta Bowl - Wari    Rice Dishes  3.8/5
# 12     Wari                Kacchi Bhai - Wari        Biryani  3.9/5
# ...

# %%
df.to_csv("Wari_data.csv",index=False)
df.head()
# Out:
#   Location                       Restuarants      Cuisine Rating
# 0     Wari                   Alfresco - Wari    Fast Food    4/5
# 1     Wari                      Khana's-Wari    Fast Food    4/5
# 2     Wari             Cafe Appeliano - Wari    Fast Food  3.8/5
# 3     Wari    Star Kabab & Restaurant - Wari  Bangladeshi    4/5
# 4     Wari  Simla Dosa & Mini Chinese - Wari    Fast Food  3.2/5

# %%
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
from time import sleep
import numpy as np

path = r"/Users/tabassumtanzim/Downloads/chromedriver-mac-arm64/chromedriver"

# Create Chrome object
options = webdriver.ChromeOptions()
options.add_argument(f"webdriver.chrome.driver={path}")

driver = webdriver.Chrome(options=options)
driver.get("https://www.foodpanda.com.bd/restaurants/new/?lat=23.77485&lng=90.36537&vertical=restaurants&expedition=delivery&query=shaymoli+restaurant")



title=[]
cuisine=[]
rating=[]
location='Shaymoli'


for i in range (1,20):
    if (driver.find_element(By.XPATH, '//*[@id="restaurant-listing-root"]/div/div/div[2]/div[2]/div/div/div/div[4]/section/ul/li[' + str(i) + ']/div/a/figure/figcaption/span/span[1]').text != 'Top restaurant'):
        try:
            title.append(driver.find_element(By.XPATH, '//*[@id="restaurant-listing-root"]/div/div/div[2]/div[2]/div/div/div/div[4]/section/ul/li[' + str(i) + ']/div/a/figure/figcaption/span/span[1]').text)
        except:
            title.append(driver.find_element(By.XPATH, '//*[@id="restaurant-listing-root"]/div/div/div[2]/div[2]/div/div/div/div[4]/section/ul/li[' + str(i) + ']/div/a/figure/figcaption/span/span[2]').text)

                                    
        cuisine.append(driver.find_element(By.XPATH, '//*[@id="restaurant-listing-root"]/div/div/div[2]/div[2]/div/div/div/div[4]/section/ul/li[' + str(i) + ']/div/a/figure/figcaption/ul[1]/li[2]/span').text)
      
        try:
            rating.append(driver.find_element(By.XPATH,'//*[@id="restaurant-listing-root"]/div/div/div[2]/div[2]/div/div/div/div[4]/section/ul/li[' + str(i) + ']/div/a/figure/figcaption/span/span[2]/div/div/span[1]').text)
        except:
            rating.append(driver.find_element(By.XPATH,'//*[@id="restaurant-listing-root"]/div/div/div[2]/div[2]/div/div/div/div[4]/section/ul/li[' + str(i) + ']/div/a/figure/figcaption/span/span[3]/div/div/span[1]').text)
              

                          
print(title)        
print(cuisine)
print(rating)
# Out:
# ['Mollah bhorta House', 'Cafe Mohammadia Hotel & Restaurant', 'Hello Mohammadpur Cafe', 'Shahjalal Shah Poran Hotel And Restaurant', 'Arju Biryani and Restaurant', 'Bangaliana Bhoj - Mohammadpur', 'Trisna Hotel & Restaurant - Mohammadpur', 'Mejbani Bhojon', 'Kutum Bari', 'Bhorta Bari', 'Chittagong Xpress', 'Bismillah Hotel Restaurant & Kabab Ghar', 'City Cafe - Dhanmondi', 'Bhorta Express', 'Cafe Tawa']
# ['Bangladeshi', 'Bangladeshi', 'Bangladeshi', 'Bangladeshi', 'Biryani', 'Bangladeshi', 'Bangladeshi', 'Bangladeshi', 'Bangladeshi', 'Bangladeshi', 'Bangladeshi', 'Bangladeshi', 'Bangladeshi', 'Bangladeshi', 'Bangladeshi']
# ['3.9/5', '3.8/5', '3.9/5', '3.7/5', '3.1/5', '3/5', '4/5', '4/5', '3.9/5', '3.3/5', '4.1/5', '3.4/5', '3.8/5', '3.7/5', '4/5']

# %%
data = {'Location':location,'Restuarants': title, 'Cuisine': cuisine, 'Rating': rating}
df=pd.DataFrame(data)
df
# Out:
#     Location                                Restuarants      Cuisine Rating
# 0   Shaymoli                        Mollah bhorta House  Bangladeshi  3.9/5
# 1   Shaymoli         Cafe Mohammadia Hotel & Restaurant  Bangladeshi  3.8/5
# 2   Shaymoli                     Hello Mohammadpur Cafe  Bangladeshi  3.9/5
# 3   Shaymoli  Shahjalal Shah Poran Hotel And Restaurant  Bangladeshi  3.7/5
# 4   Shaymoli                Arju Biryani and Restaurant      Biryani  3.1/5
# 5   Shaymoli              Bangaliana Bhoj - Mohammadpur  Bangladeshi    3/5
# 6   Shaymoli    Trisna Hotel & Restaurant - Mohammadpur  Bangladeshi    4/5
# 7   Shaymoli                             Mejbani Bhojon  Bangladeshi    4/5
# 8   Shaymoli                                 Kutum Bari  Bangladeshi  3.9/5
# 9   Shaymoli                                Bhorta Bari  Bangladeshi  3.3/5
# 10  Shaymoli                          Chittagong Xpress  Bangladeshi  4.1/5
# ...
